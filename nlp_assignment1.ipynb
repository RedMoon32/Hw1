# %%
from io import open
from sklearn.metrics import accuracy_score
from conllu import parse_incr
import random

# %%
SYNTAG = 'ud-treebanks-v2.5/UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu'

# %%
from enum import IntEnum, auto

class POS(IntEnum):
    START = 0
    ADJ = auto()
    ADP = auto()
    ADV = auto()
    AUX = auto()
    CCONJ = auto()
    DET = auto()
    INTJ = auto()
    NOUN = auto()
    NUM = auto()
    PART = auto()
    PRON = auto()
    PROPN = auto()
    PUNCT = auto()
    SCONJ = auto()
    SYM = auto()
    VERB = auto()
    X = auto()
    END = auto()

items = POS
items
# Out:
# <enum 'POS'>

# %%
def wrap_tags(tags):
    return [POS.START] + tags + [POS.END]

def parse_tags(tt):
    tags = []
    for i, tag in enumerate(tt):
        if tag in POS.__dict__.keys():
            tags.append(POS.__dict__[tag])
        else:
            tags.append(POS.X)

    return wrap_tags(tags)

# %%
def add_tag_token_helper(token, tokens, tags):
    tokens.append(token['lemma'].lower())
    tags.append(token['upostag'])
    
def parse_sent(sent):
    tokens = []
    tags = []
    for token in sent:
        if token['lemma'] != '_' and token['upostag'] != '_':
            add_tag_token_helper(token, tokens, tags)

    return tokens, parse_tags(tags)

# %%
def read_dataset(data_path):
    data_file = open(data_path, "r", encoding="utf-8")
    ss = parse_incr(data_file)
    return list(ss)

# %%
read_dataset(SYNTAG)
# Out:
# [TokenList<Анкета, .>,
#  TokenList<Начальник, областного, управления, связи, Семен, Еремеевич, был, человек, простой, ,, приходил, на, работу, всегда, вовремя, ,, здоровался, с, секретаршей, за, руку, и, иногда, даже, писал, в, стенгазету, заметки, под, псевдонимом, ", Муха, ", .>,
#  TokenList<В, приемной, его, с, утра, ожидали, посетители, ,, -, кое-кто, с, важными, делами, ,, а, кое-кто, и, с, такими, ,, которые, легко, можно, было, решить, в, нижестоящих, инстанциях, ,, не, затрудняя, Семена, Еремеевича, .>,
#  TokenList<Однако, стиль, работы, Семена, Еремеевича, заключался, в, том, ,, чтобы, принимать, всех, желающих, и, лично, вникать, в, дело, .>,
#  TokenList<Приемная, была, обставлена, просто, ,, но, по-деловому, .>,
#  TokenList<У, двери, стоял, стол, секретарши, ,, на, столе, -, пишущая, машинка, с, широкой, кареткой, .>,
#  TokenList<В, углу, висел, репродуктор, и, играло, радио, для, развлечения, ожидающих, и, еще, для, того, ,, чтобы, заглушать, голос, начальника, ,, доносившийся, из, кабинета, ,, так, как, ,, бесспорно, ,, среди, посетителей, могли, находиться, и, случайные, люди, .>,
#  TokenList<Кабинет, отличался, скромностью, ,, присущей, Семену, Еремеевичу, .>,
#  TokenList<В, глубине, стоял, широкий, письменный, стол, с, бронзовыми, чернильницами, и, перед, ним, два, кожаных, кресла, .>,
#  TokenList<Справа, был, стол, для, заседаний, -, длинный, ,, накрытый, зеленым, сукном, и, с, обеих, сторон, аккуратно, заставленный, стульями, .>,
#  TokenList<Семен, Еремеевич, очень, не, любил, ,, когда, за, этот, стол, кто-нибудь, садился, ,, и, если, видел, отодвинутый, стул, ,, то, всегда, собственноручно, подвигал, его, на, место, ,, так, чтобы, спинки, образовывали, ровную, прямую, линию, .>,
#  TokenList<В, тот, день, ,, с, которого, начинается, наш, рассказ, ,, жизнь, в, приемной, протекала, обычно, .>,
#  TokenList<Секретарша, ставила, сургучные, печати, на, пакет, ,, посетители, ожидали, своей, очереди, ,, радио, играло, сентиментальный, вальс, .>,
#  TokenList<Ровно, в, десять, часов, раздался, короткий, звонок, .>,
#  TokenList<Быстрая, секретарша, на, минуту, скрылась, в, кабинете, и, проговорила, ,, вернувшись, :, -, Товарищ, Ефимова, ,, пожалуйста, .>,
#  TokenList<Молодая, женщина, в, кокетливой, шляпке, прошла, в, кабинет, .>,
#  TokenList<Она, ,, видимо, ,, волновалась, ,, потому, что, забыла, закрыть, за, собой, обе, обитые, черной, клеенкой, двери, .>,
#  TokenList<Семен, Еремеевич, медленно, писал, ,, склонив, по, привычке, голову, набок, .>,
#  TokenList<-, Садитесь, ,, пожалуйста, ,, -, сказал, он, ,, не, поднимая, глаз, .>,
#  TokenList<Ефимова, села, на, краешек, холодного, кресла, и, посмотрела, сквозь, бронзовый, забор, чернильного, прибора, на, Семена, Еремеевича, .>,
#  TokenList<У, него, было, полное, симпатичное, лицо, некурящего, человека, и, белые, ,, совершенно, седые, волосы, .>,
#  TokenList<-, Да, ,, я, вас, слушаю, ,, -, сказал, он, ,, продолжая, писать, .>,
#  TokenList<-, Моя, фамилия, Ефимова, ,, -, тихо, кашлянув, ,, начала, женщина, давно, приготовленную, и, отредактированную, в, уме, фразу, .>,
#  TokenList<-, Я, была, у, вас, неделю, тому, назад, по, вопросу, устройства, на, работу, .>,
#  TokenList<Вы, взяли, мою, автобиографию, и, анкету, и, предложили, мне, прийти, сегодня, …>,
#  TokenList<Начальник, молча, писал, .>,
#  TokenList<Она, взглянула, на, него, ,, как, будто, не, понимая, ,, что, надо, просто, сесть, и, подождать, .>,
#  TokenList<-, Да, ,, -, отозвался, Семен, Еремеевич, .>,
#  TokenList<Начальнику, трудно, было, переключить, внимание, .>,
#  TokenList<Перед, ним, лежала, копия, жалобы, жителей, села, Веселого, на, плохую, работу, трансляционной, сети, .>,
#  TokenList<Жалоба, каким-то, образом, попала, в, Москву, .>,
#  TokenList<Оттуда, и, пришла, эта, копия, и, вместе, с, ней, распоряжение, ,, в, котором, предлагалось, немедленно, ликвидировать, перебои, ,, наказать, виновных, и, доложить, об, исполнении, к, такому-то, числу, .>,
#  TokenList<(, Число, это, вчера, прошло, ., )>,
#  TokenList<Распоряжение, было, написано, резко, и, содержало, обидные, для, Семена, Еремеевича, намеки, на, плохое, руководство, .>,
#  TokenList<На, такие, письма, начальник, составлял, ответы, сам, .>,
#  TokenList<В, первую, очередь, ,, как, это, и, положено, ,, он, вывел, в, верхнем, углу, гриф, ", секретно, ", .>,
#  TokenList<Затем, он, написал, ,, что, летом, трансляционная, сеть, в, некоторых, районах, области, работала, недостаточно, четко, в, связи, с, тем, ,, что, на, линии, перегорали, трансформаторы, .>,
#  TokenList<", Ну, и, народ, у, меня, в, отделе, кадров, ,, -, подумал, он, .>,
#  TokenList<-, Боятся, ответственности, ,, как, черти, _, ладана, ", .>,
#  TokenList<Сложность, вопроса, заключалась, в, том, ,, что, во, время, войны, Ефимова, находилась, в, оккупации, .>,
#  TokenList<Из-за, этого, обстоятельства, документы, ее, и, перекочевали, из, несгораемого, шкафа, отдела, кадров, в, письменный, стол, Семена, Еремеевича, .>,
#  TokenList<Из-за, этого, в, прошлую, среду, Семен, Еремеевич, и, попросил, ее, зайти, через, неделю, .>,
#  TokenList<После, окончания, института, Ефимова, два, года, работала, линейным, инженером, на, радиоузле, у, Савельева, и, уволилась, в, 1952, году, ,, как, было, написано, в, анкете, ,, ", по, семейным, обстоятельствам, ", .>,
#  TokenList<За, неделю, начальник, управления, собирался, позвонить, Савельеву, ,, который, занимал, теперь, такой, же, пост, ,, как, и, Семен, Еремеевич, в, соседней, области, ,, и, узнать, о, деловых, качествах, Ефимовой, .>,
#  TokenList<Если, Савельев, не, похвалит, Ефимову, ,, можно, с, чистой, совестью, отказать, ей, и, покончить, с, этим, щекотливым, вопросом, .>,
#  TokenList<Однако, Семен, Еремеевич, ,, загруженный, текучкой, ,, не, успел, сделать, это, .>,
#  TokenList<Он, попросил, Евгению, Васильевну, подождать, еще, недельку, и, ,, как, только, она, вышла, ,, заказал, междугородный, разговор, .>,
#  TokenList<Но, Савельев, несерьезно, отнесся, к, вопросу, .>,
#  TokenList<Он, сказал, ,, что, Ефимова, честный, ,, квалифицированный, работник, ,, и, выразил, готовность, дать, ей, характеристику, .>,
#  TokenList<-, А, не, кажется, тебе, ,, что, ей, трудно, придется, на, линии, ?, -, спросил, Семен, Еремеевич, .>,
#  TokenList<-, Слабовольная, она, какая-то, ,, бесхарактерная, .>,
#  TokenList<Пугливая, какая-то, …>,
#  TokenList<Савельеву, этого, не, казалось, .>,
#  TokenList<По, его, мнению, ,, Ефимова, всегда, была, настойчива, и, требовательна, .>,
#  TokenList<-, А, как, она, по, бытовой, линии, ?, -, спросил, Семен, Еремеевич, .>,
#  TokenList<-, То, женится, ,, то, разводится, .>,
#  TokenList<Несерьезно, как-то, …>,
#  TokenList<Савельев, объяснил, ,, что, вышла, замуж, за, диктора, районного, радиоузла, .>,
#  TokenList<Муж, настоял, ,, чтобы, она, бросила, работу, .>,
#  TokenList<Вскоре, после, этого, стало, известно, ,, что, у, диктора, где-то, в, деревне, остались, жена, и, ребенок, .>,
#  TokenList<И, Ефимова, развелась, ,, ", И, ,, по-моему, ,, правильно, сделала, ", ,, -, добавил, Савельев, .>,
#  TokenList<-, А, тебе, известно, ,, что, она, уже, пол, года, не, работает, ?>,
#  TokenList<Это, Савельеву, известно, не, было, .>,
#  TokenList<-, Ну, вот, ,, -, сказал, Семен, Еремеевич, .>,
#  TokenList<-, Надо, изучать, своих, работников, .>,
#  TokenList<-, Да, ты, бери, ее, ,, бери, !, -, закричал, Савельев, .>,
#  TokenList<-, Не, пожалеешь, !>,
#  TokenList<На, этом, разговор, закончился, .>,
#  TokenList<Конечно, ,, Савельеву, легко, было, рассуждать, ,, поскольку, Ефимова, прибыла, к, нему, с, направлением, главка, .>,
#  TokenList<А, Семен, Еремеевич, должен, брать, ее, сам, ,, на, свою, личную, ответственность, .>,
#  TokenList<Формально, ,, конечно, ,, для, зачисления, Ефимовой, не, было, препятствий, ,, но, если, взглянуть, на, вопрос, поглубже, -, анкета, все-таки, не, чистая, .>,
#  TokenList<Возьмешь, ,, а, потом, не, оберешься, неприятностей, .>,
#  TokenList<Приедет, ,, например, ,, ревизия, ,, поднимет, личные, дела, -, вот, и, неприятность, .>,
#  TokenList<В, техническом, отделе, один, из, дворян, по, происхождению, ,, другой, до, революции, черт, знает, кем, был, …, чуть, ли, не, дьяконом, -, в, общем, не, нашей, масти, .>,
#  TokenList<А, тут, еще, эта, .>,
#  TokenList<Понятно, ,, скажут, ,, почему, тут, у, вас, трансформаторы, перегорают, .>,
#  TokenList<Окружили, себя, негодными, людьми, ,, притупилась, бдительность, .>,
#  TokenList<Еще, ротозейство, пришьют, …>,
#  TokenList<Через, неделю, Ефимова, опять, сидела, в, кабинете, Семена, Еремеевича, .>,
#  TokenList<Как, у, вас, с, семейным, положением, ?, -, спросил, начальник, .>,
#  TokenList<Я, живу, с, папой, и, мамой, ,, -, заговорила, Евгения, Васильевна, .>,
#  TokenList<-, На, Кирпичной, улице, ,, дом, десять, .>,
#  TokenList<-, Это, там, ,, возле, Первомайского, садика, ?>,
#  TokenList<-, Да, ,, да, ,, возле, садика, ,, маленький, такой, домик, .>,
#  TokenList<Два, крайних, окна, -, наши, ,, остальные, -, соседей, .>,
#  TokenList<Мама, работает, на, кирпичном, заводе, .>,
#  TokenList<А, папа, совсем, старенький, .>,
#  TokenList<Инвалид, .>,
#  TokenList<Приходится, возить, на, коляске, .>,
#  TokenList<-, У, него, ,, что, же, ,, _, ручная, коляска, ?>,
#  TokenList<-, Да, ,, такая, легонькая, …>,
#  TokenList<С, рычагами, .>,
#  TokenList<А, он, слабенький, ,, рычаги, не, может, двигать, .>,
#  TokenList<-, Надо, бы, ему, моторную, заказать, .>,
#  TokenList<Наша, промышленность, теперь, изготовляет, моторные, .>,
#  TokenList<-, Просили, ,, не, дают, .>,
#  TokenList<Требуют, целую, кучу, справок, .>,
#  TokenList<Такая, постановка, дела, возмутила, Семена, Еремеевича, .>,
#  TokenList<-, Какое, безобразие, ,, -, сказал, он, .>,
#  TokenList<-, А, вы, настойчивей, действуйте, .>,
#  TokenList<Напишите, в, газету, .>,
#  TokenList<В, Москву, ,, в, крайнем, случае, .>,
#  TokenList<-, Спасибо, .>,
#  TokenList<Вы, знаете, ,, ведь, я, из-за, папы, и, живу, тут, .>,
#  TokenList<А, то, бы, давно, уехала, к, Савельеву, ,, он, бы, меня, взял, .>,
#  TokenList<-, Значит, ,, в, отъезд, вы, не, можете, ?>,
#  TokenList<-, Вы, же, сами, понимаете, ,, как, это, мне, трудно, .>,
#  TokenList<-, Да, ,, жаль, .>,
#  TokenList<А, я, вам, уже, подобрал, место, на, периферии, .>,
#  TokenList<-, Где, ?>,
#  TokenList<-, В, селе, Веселом, .>,
#  TokenList<Там, линейный, инженер, вот, так, нужен, .>,
#  TokenList<-, И, далеко, это, село, ?>,
#  TokenList<-, Около, сотни, километров, отсюда, .>,
#  TokenList<Кажется, ,, сто, двенадцать, .>,
#  TokenList<-, Туда, я, никак, не, смогу, ,, -, сказала, Ефимова, со, свойственной, большинству, посетителей, несговорчивостью, .>,
#  TokenList<-, А, нельзя, где-нибудь, поближе, ?>,
#  TokenList<Я, ведь, согласна, ездить, .>,
#  TokenList<Только, так, ,, чтобы, вечерами, быть, дома, .>,
#  TokenList<-, Да, разве, я, не, понимаю, ,, -, мягко, улыбнулся, Семен, Еремеевич, .>,
#  TokenList<-, Представляю, ваше, положение, .>,
#  TokenList<В, свое, время, тоже, с, отцом, намучился, .>,
#  TokenList<-, Что, вы, !>,
#  TokenList<Я, нисколько, не, мучаюсь, …>,
#  TokenList<А, может, ,, появится, место, где-нибудь, поближе, ?>,
#  TokenList<-, Трудно, сказать, .>,
#  TokenList<Зайдите, через, недельку, .>,
#  TokenList<Через, неделю, Ефимова, снова, пришла, к, нему, .>,
#  TokenList<На, этот, раз, она, была, в, сильном, возбуждении, и, мяла, в, кулаке, кружевной, платочек, .>,
#  TokenList<-, Как, с, моим, делом, ,, товарищ, начальник, ?, -, спросила, она, ,, сознательно, не, называя, Семена, Еремеевича, по, имени, -, отчеству, .>,
#  TokenList<-, Пока, еще, ничего, нет, .>,
#  TokenList<Кроме, села, Веселого, ,, ничего, нет, ,, -, тактично, не, обращая, внимания, на, ее, тон, ,, ответил, начальник, .>,
#  TokenList<-, В, Веселом, очень, нужен, линейный, инженер, .>,
#  TokenList<-, Ваша, секретарша, только, что, передо, мной, печатала, приказ, о, назначении, техника, на, городской, узел, …>,
#  TokenList<Значит, ,, у, вас, были, вакансии, .>,
#  TokenList<И, ,, вероятно, ,, есть, .>,
#  TokenList<Вы, просто, говорили, неправду, .>,
#  TokenList<Какой-нибудь, другой, руководитель, учреждения, в, ответ, на, такой, выпад, быстро, призвал, бы, посетителя, к, порядку, .>,
#  TokenList<Но, Семен, Еремеевич, не, стал, ни, кричать, ,, ни, браниться, .>,
#  TokenList<Он, только, встал, со, своего, стула, и, сказал, сдержанно, :, -, Товарищ, Ефимова, !>,
#  TokenList<-, Я, догадываюсь, ,, в, чем, дело, .>,
#  TokenList<-, Ефимова, тоже, встала, .>,
#  TokenList<Бледные, щеки, ее, покрылись, пятнами, .>,
#  TokenList<-, Вас, пугает, ,, что, я, была, в, оккупации, .>,
#  TokenList<-, Да, что, вы, ,, при, чем, тут, оккупация, ?>,
#  TokenList<-, Семен, Еремеевич, сел, и, поправил, стопку, папок, .>,
#  TokenList<Он, очень, любил, ,, чтобы, на, письменном, столе, всегда, был, полный, ,, можно, даже, сказать, ,, блестящий, порядок, .>,
#  TokenList<И, если, оказывался, ,, например, ,, неочиненный, карандаш, или, неполная, чернильница, ,, он, всегда, вызывал, секретаршу, и, делал, ей, соответствующее, внушение, .>,
#  TokenList<-, Нет, ,, разрешите, ,, я, вам, все-таки, объясню, ,, -, не, унималась, Ефимова, .>,
#  TokenList<-, Наш, институт, в, самом, начале, войны, эвакуировался, в, Пятигорск, из, осажденного, Ленинграда, .>,
#  TokenList<В, Пятигорске, мы, продолжали, занятия, .>,
#  TokenList<Потом, ,, когда, фронт, пододвинулся, ,, нас, со, дня, на, день, обещали, перевезти, в, Среднюю, Азию, .>,
#  TokenList<Но, не, успели, .>,
#  TokenList<Ребята, ,, которые, посмелей, ,, конечно, ,, уехали, на, крышах, и, на, подножках, ,, а, я, не, могла, так, …>,
#  TokenList<На, вокзале, билетов, не, достать, …>,
#  TokenList<В, чужие, эшелоны, не, пускали, …>,
#  TokenList<Потом, мы, пошли, пешком, …>,
#  TokenList<Потом, нас, окружили, …>,
#  TokenList<Очень, тяжелое, было, время, …>,
#  TokenList<-, Помню, это, время, ,, помню, ,, -, Семен, Еремеевич, вздохнул, .>,
#  TokenList<-, Меня, самого, из, Крыма, в, последнюю, минуту, вывезли, ,, -, и, поправил, на, столе, папки, .>,
#  TokenList<-, Вас, -, то, ,, конечно, ,, надо, было, вывезти, .>,
#  TokenList<-, Да, ,, приказ, был, из, центра, .>,
#  TokenList<Немедленно, выехать, .>,
#  TokenList<А, я, уж, мечтал, связаться, с, партизанами, ,, -, натура, у, меня, с, детства, партизанская, .>,
#  TokenList<Но, ничего, не, вышло, ,, приказ, есть, приказ, .>,
#  TokenList<-, Я, тоже, хотела, связаться, с, партизанами, .>,
#  TokenList<Только, не, знала, ,, где, они, помещаются, .>,
#  TokenList<-, Какая, из, вас, партизанка, !>,
#  TokenList<И, долго, вы, находились, у, немцев, ?>,
#  TokenList<-, Пять, месяцев, .>,
#  TokenList<Пришлось, работать, учительницей, .>,
#  TokenList<Надо, же, было, чем-нибудь, жить, ?>,
#  TokenList<Я, ,, конечно, ,, виновата, ,, что, не, пошла, в, партизаны, …>,
#  TokenList<Сейчас, бы, я, в, любой, системе, стала, работать, ,, на, простой, технической, должности, .>,
#  TokenList<Все, равно, не, берут, .>,
#  TokenList<-, Перестраховщики, .>,
#  TokenList<-, Нет, ,, не, перестраховщики, .>,
#  TokenList<Есть, указание, ,, что, человека, с, высшим, образованием, не, имеют, права, держать, на, рядовой, работе, .>,
#  TokenList<Вы, не, улыбайтесь, ,, -, это, правильное, указание, .>,
#  TokenList<Нас, учили, ,, на, нас, тратили, деньги, .>,
#  TokenList<И, мы, должны, работать, в, полную, силу, .>,
#  TokenList<Между, прочим, ,, я, доучивалась, после, войны, и, дирекция, института, знала, ,, что, я, была, в, оккупации, .>,
#  TokenList<-, Да, ,, -, Семен, Еремеевич, вздохнул, ,, -, узкую, вам, дали, специальность, .>,
#  TokenList<-, Я, пыталась, ее, переменить, .>,
#  TokenList<Недавно, подавала, заявление, в, институт, иностранных, языков, .>,
#  TokenList<Но, они, сказали, :, ", У, вас, уже, есть, высшее, образование, ,, поэтому, ваше, заявление, будем, рассматривать, в, последнюю, очередь, .>,
#  TokenList<Если, останутся, места, ", .>,
#  TokenList<-, Перестраховщики, ,, -, снова, сказал, Семен, Еремеевич, .>,
#  TokenList<-, А, по-моему, ,, правильно, .>,
#  TokenList<Другие, тоже, хотят, иметь, высшее, образование, .>,
#  TokenList<Но, что, мне, делать, ,, прямо, не, знаю, .>,
#  TokenList<Лучше, без, руки, или, без, ноги, жить, ,, чем, без, работы, .>,
#  TokenList<Она, посмотрела, перед, собой, куда-то, в, пространство, и, спросила, :, -, А, как, туда, ехать, ,, в, это, Веселое, село, ?>,
#  TokenList<Семен, Еремеевич, терпеливо, объяснил, ,, что, ехать, придется, сначала, на, поезде, ,, а, потом, автобусом, .>,
#  TokenList<От, автобусной, станции, километра, три, ,, не, больше, .>,
#  TokenList<Но, следует, иметь, в, виду, ,, что, автобусы, зимой, ходят, нерегулярно, ,, особенно, во, время, снежных, заносов, .>,
#  TokenList<И, билеты, на, поезд, -, за, свой, счет, .>,
#  TokenList<Но, в, общем, транспорт, нормальный, .>,
#  TokenList<А, вот, по, поводу, жилья, в, Веселом, нельзя, сказать, ничего, утешительного, .>,
#  TokenList<Единственная, возможность, -, снять, частную, квартиру, .>,
#  TokenList<Семен, Еремеевич, вышел, из-за, стола, ,, попрощался, с, Ефимовой, за, руку, и, предложил, ей, зайти, на, всякий, случай, через, недельку, -, две, .>,
#  TokenList<Через, две, недели, Ефимова, пришла, радостная, .>,
#  TokenList<И, губы, ее, уже, не, были, накрашены, .>,
#  TokenList<-, Знаете, ,, все, устроилось, ,, Семен, Еремеевич, !, -, начала, она, ,, даже, не, поздоровавшись, .>,
#  TokenList<-, Директор, кирпичного, завода, по, моей, просьбе, перевел, маму, во, вторую, смену, .>,
#  TokenList<А, по, утрам, к, нам, будет, приходить, девушка, ,, дальняя, родственница, соседей, .>,
#  TokenList<Она, недавно, приехала, из, деревни, .>,
#  TokenList<Будет, готовить, обед, ,, убираться, .>,
#  TokenList<А, по, воскресеньям, я, стану, приезжать, домой, .>,
#  TokenList<Правильно, ?>,
#  TokenList<-, Где, же, вы, устроились, ?, -, спросил, Семен, Еремеевич, .>,
#  TokenList<-, Как, где, ?>,
#  TokenList<Я, поеду, в, Веселое, .>,
#  TokenList<-, Ах, вот, что, …>,
#  TokenList<-, Семен, Еремеевич, опустил, глаза, и, поправил, папки, .>,
#  TokenList<-, Видите, ли, ,, мы, не, могли, тянуть, столько, времени, .>,
#  TokenList<В, Веселом, штаты, укомплектованы, .>,
#  TokenList<Ефимова, медленно, поднялась, с, кресла, и, стала, оглядываться, вокруг, .>,
#  TokenList<-, Вы, же, говорили, …, -, начала, она, .>,
#  TokenList<Вы, же, сказали, …>,
#  TokenList<-, Через, две, недели, .>,
#  TokenList<У, вас, …>,
#  TokenList<И, вдруг, ,, отвернувшись, ,, закрыла, лицо, руками, и, выбежала, из, кабинета, .>,
#  TokenList<И, снова, ,, между, прочим, ,, за, ней, пришлось, закрывать, обе, двери, .>,
#  TokenList<Больше, Ефимова, не, приходила, .>,
#  TokenList<Семен, Еремеевич, ,, кажется, ,, не, обратил, на, это, особенного, внимания, и, постепенно, совсем, забыл, о, докучливой, посетительнице, .>,
#  TokenList<Но, как-то, ,, наводя, порядок, в, письменном, столе, ,, он, наткнулся, на, коротенькую, автобиографию, .>,
#  TokenList<Пробежав, глазами, строчки, со, смешными, хвостиками, в, буквах, ", д, ", ,, он, снова, вспомнил, женщину, в, шляпке, с, перьями, и, задумался, .>,
#  TokenList<Что, с, ней, случилось, ?>,
#  TokenList<Где, она, сейчас, ?>,
#  TokenList<Может, быть, ,, устроилась, где-нибудь, ?>,
#  TokenList<Вряд, ли, .>,
#  TokenList<Все, ее, справки, и, характеристики, остались, здесь, .>,
#  TokenList<Да, и, работать, она, может, только, в, системе, связи, ,, у, нее, узкая, специальность, .>,
#  TokenList<Может, быть, ,, она, отправилась, в, Москву, жаловаться, ,, добралась, до, министра, ?>,
#  TokenList<Если, это, так, ,, то, со, дня, на, день, надо, ожидать, строгого, запроса, от, людей, ,, не, вникающих, в, суть, дела, :, на, каком, основании, инженер, Ефимова, не, зачисляется, на, работу, ?>,
#  TokenList<Сами, ,, мол, ,, пишете, ,, что, не, хватает, специалистов, ,, а, специалисты, обивают, ваши, пороги, .>,
#  TokenList<Что, можно, ответить, на, такой, запрос, ?>,
#  TokenList<Семен, Еремеевич, вызвал, секретаршу, и, ,, разбирая, дела, ,, поинтересовался, ,, не, записывалась, ли, на, прием, такая, худенькая, женщина, ,, по, фамилии, ,, кажется, ,, Ефимова, .>,
#  TokenList<В, списках, Ефимовой, не, было, .>,
#  TokenList<Семен, Еремеевич, снова, задумался, .>,
#  TokenList<Может, быть, ,, ему, вспомнился, давний, случай, с, женщиной, ,, которую, долго, не, принимали, на, работу, ,, потому, что, муж, ее, оказался, замешанным, в, какую-то, непонятную, историю, и, был, арестован, .>,
#  TokenList<Женщина, написала, о, своих, мытарствах, куда, следует, и, бросилась, в, реку, .>,
#  TokenList<Конечно, ,, такой, случай, ,, хотя, он, произошел, и, не, в, нашей, системе, и, много, лет, назад, ,, не, мог, не, оставить, следа, на, впечатлительной, натуре, Семена, Еремеевича, .>,
#  TokenList<Он, стал, нервничать, .>,
#  TokenList<На, руках, его, ,, так, же, ,, как, и, в, прошлом, году, ,, когда, приезжали, представители, главка, ,, появились, красные, пятнышки, .>,
#  TokenList<Через, три, недели, ,, чтобы, покончить, с, неизвестностью, ,, Семен, Еремеевич, приказал, было, послать, пользующегося, его, доверием, сотрудника, на, квартиру, Ефимовой, ,, но, ,, посоветовавшись, с, ним, ,, спохватился, и, отменил, приказ, .>,
#  TokenList<Во, всех, случаях, такое, посещение, выглядело, бы, странным, и, по, меньшей, мере, несолидным, .>,
#  TokenList<Наконец, Семен, Еремеевич, решил, ни, о, чем, не, думать, и, терпеливо, дожидаться, душевного, равновесия, .>,
#  TokenList<Но, смутная, тревога, с, каждым, днем, звучала, сильней, и, настойчивей, в, его, отзывчивом, сердце, .>,
#  TokenList<-, Я, тоже, придерживал, для, вас, место, ,, но, вы, долго, не, заходили, .>,
#  TokenList<-, Меня, не, было, в, городе, .>,
#  TokenList<Я, ездила, копать, картошку, .>,
#  TokenList<-, Как, же, вас, угораздило, ?>,
#  TokenList<-, От, кирпичного, завода, послали, маму, .>,
#  TokenList<Но, ей, трудно, ,, и, я, поехала, вместо, нее, .>,
#  TokenList<Кстати, ,, до, села, Веселого, не, сто, ,, а, семьдесят, два, километра, .>,
#  TokenList<-, Вы, были, в, Веселом, ?>,
#  TokenList<-, Да, .>,
#  TokenList<И, видела, ,, что, творится, там, на, радиоузле, .>,
#  TokenList<-, А, что, такое, ?>,
#  TokenList<-, Монтеры, торгуют, казенным, проводом, .>,
#  TokenList<Говорят, легковерным, абонентам, ,, что, на, складе, нет, материалов, .>,
#  TokenList<И, якобы, достают, провод, для, ввода, сами, .>,
#  TokenList<И, за, это, берут, деньги, .>,
#  TokenList<-, Безобразие, ,, -, сказал, Семен, Еремеевич, .>,
#  TokenList<-, Куда, же, там, руководство, смотрит, ?>,
#  TokenList<-, Так, там, же, некому, смотреть, .>,
#  TokenList<Там, пол, года, нет, линейного, инженера, .>,
#  TokenList<У, вас, там, полный, беспорядок, ,, а, вы, …, а, вы, только, бумажки, читаете, .>,
#  TokenList<Ефимова, повернулась, и, вышла, ,, не, попрощавшись, .>,
#  TokenList<", Какие, все-таки, нервные, ,, несдержанные, посетители, ,, -, подумал, Семен, Еремеевич, .>,
#  TokenList<Он, снисходительно, покачал, головой, и, потянулся, к, папке, ,, на, которой, было, написано, ", переписка, с, вышестоящими, инстанциями, .>,
#  TokenList<Военные, конструкторы, и, ученые, многих, армий, мира, уделяют, огромное, внимание, и, затрачивают, огромные, средства, для, создания, все, более, сложных, и, дорогих, систем, высокоточного, оружия, для, полного, уничтожения, цели, и, исключения, потерь, среди, мирного, населения, .>,
#  TokenList<Вместе, с, тем, ,, в, настоящее, время, большое, значение, придается, разработкам, новых, видов, не, смертельного, оружия, ,, которое, будет, использоваться, в, военных, конфликтах, .>,
#  TokenList<Условия, современных, войн, таковы, ,, что, только, несмертельное, оружие, позволяет, быстро, пленить, противника, ,, существенно, уменьшить, его, боеспособность, и, потери, со, своей, стороны, .>,
#  TokenList<В, новейших, конструкциях, несмертельного, оружия, используются, как, традиционные, решения, из, арсенала, стрелкового, вооружения, ,, так, и, новые, биофизические, эффекты, ,, достижения, химии, ,, биохимии, ,, электроники, и, других, прикладных, наук, .>,
#  TokenList<Украинское, научно, -, производственное, предприятие, ", ВАЛАР, ", создало, новый, переносной, комплекс, ", КОБА, ", для, обеспечения, боевых, действий, сил, специального, назначения, .>,
#  TokenList<Кроме, того, ,, новое, несмертельное, оружие, может, эффективно, использоваться, для, ведения, охранных, мероприятий, ,, защиты, блокпостов, ,, границ, и, может, успешно, использоваться, полицейскими, подразделениями, для, борьбы, с, антиправительственными, демонстрантами, и, уличными, беспорядками, .>,
#  TokenList<Конструктивно, комплекс, ", КОБА, ", выполнен, в, виде, трансформируемого, компактного, контейнера, ,, который, переносится, на, спине, одним, бойцом, в, сложенном, виде, и, снаряжен, двумя, зарядами, .>,
#  TokenList<Дополнительный, боекомплект, может, переноситься, в, ранце, .>,
#  TokenList<Новое, изделие, выполняет, несколько, функций, ,, присущих, артиллерийской, системе, малого, калибра, ,, а, также, переносному, контейнеру, с, электронным, оборудованием, .>,
#  TokenList<Помимо, трансформируемого, корпуса, ,, конструкция, имеет, ", интеллектуальную, ", начинку, .>,
#  TokenList<Комплекс, снабжен, встроенными, прицельными, приспособлениями, ,, элементами, для, выверки, положения, на, грунте, ,, лазерным, целеуказателем, ,, автономным, питанием, и, другими, элементами, обеспечения, высокоточной, стрельбы, .>,
#  TokenList<Наличие, лазерного, целеуказателя, обеспечивает, точность, и, оперативность, прицеливания, и, поражения, цели, с, первого, выстрела, .>,
#  TokenList<При, необходимости, ведения, боевых, действий, контейнер, в, течение, нескольких, секунд, раскладывается, в, пусковую, установку, .>,
#  TokenList<Управление, стрельбой, электрическое, ,, по, кабелю, посредством, дистанционного, пульта, .>,
#  TokenList<Прицеливание, при, стрельбе, производится, вручную, ,, путем, изменения, наклона, стволов, от, горизонтального, уровня, грунта, .>,
#  TokenList<Прицельное, приспособление, имеет, шкалу, ,, градуированную, в, метрах, дистанции, выстрела, ,, что, упрощает, всю, операцию, .>,
#  TokenList<Для, прицеливания, в, плоскости, цели, в, конструкции, имеется, встроенный, лазерный, целеуказатель, ,, пятно, которого, уверенно, наблюдается, в, солнечный, день, на, максимальной, дистанции, выстрела, .>,
#  TokenList<Управление, целеуказателем, и, стрельбой, комплекса, ", КОБА, ", электрическое, ,, посредством, малогабаритного, дистанционного, пульта, управления, .>,
#  TokenList<Наличие, в, конструкции, двух, стволов, позволяет, оперативно, реагировать, на, изменение, ситуации, и, быстро, производить, перенацеливание, или, использование, различных, по, назначению, зарядов, на, разных, дистанциях, .>,
#  TokenList<Возможно, использование, нескольких, типов, зарядов, ,, которые, обеспечивают, широкий, спектр, задач, в, зависимости, от, боевой, обстановки, .>,
#  TokenList<Стрельба, ведется, по, навесной, траектории, на, расстояние, от, 50, до, 200, метров, .>,
#  TokenList<Наличие, навесной, траектории, обеспечивает, поражение, цели, в, городских, условиях, через, высокие, деревья, ,, здания, ,, сооружения, и, т., д, .>,
#  TokenList<Существенные, преимущества, такого, боевого, использования, особенно, выгодно, сказываются, в, условиях, населенных, пунктов, .>,
#  TokenList<В, боекомплекте, имеются, основные, заряды, ", Клещ, -, 20, ", ,, ", Сеть, -, 12, ", ,, ", Сеть, -, 12Х, ", и, некоторые, другие, заряды, специального, назначения, .>,
#  TokenList<Основной, заряд, ", Клещ, -, 20, ", обеспечивает, разбрасывание, в, зоне, поражения, специальной, сетки, -, путанки, ,, которая, компактно, уложена, в, корпусе, заряда, и, раскрывается, над, зоной, установки, на, определенной, высоте, .>,
#  TokenList<", Путанка, ", выполнена, из, проволоки, 0,4, мм, и, перекрывает, площадь, размером, около, 20, на, 20, метров, .>,
#  TokenList<В, конструкции, такой, специальной, сетки, не, только, традиционные, спирали, проволоки, ,, но, и, самозатягивающиеся, петли, ,, которые, крепко, удерживают, наступившего, на, них, противника, .>,
#  TokenList<Таким, образом, ,, в, течение, нескольких, секунд, устанавливается, заграждение, ,, которое, совершенно, непреодолимо, для, наступающего, противника, .>,
#  TokenList<Конструкция, сетки, близка, к, конструкции, широко, известного, малозаметного, препятствия, типа, МЗП-1М, ,, которое, много, лет, успешно, используется, при, охране, объектов, .>,
#  TokenList<В, реальных, боевых, действиях, все, виды, стационарного, заграждения, и, даже, малозаметного, заграждения, типа, МЗП-1М, могут, заблаговременно, выявляться, противником, .>,
#  TokenList<Новое, заграждение, может, быть, установлено, непосредственно, перед, атакующим, противником, в, самом, тактически, выгодном, и, неожиданном, для, него, месте, .>,
#  TokenList<Также, возможно, установить, заграждение, не, только, при, наступлении, противника, ,, но, и, при, его, вынужденном, отступлении, .>,
#  TokenList<Второй, заряд, ,, ", Сеть, -, 12, ", ,, выполнен, по, более, традиционной, схеме, .>,
#  TokenList<Выстрел, обеспечивает, накрытие, противника, кевларовой, сетью, диаметром, около, 12, метров, .>,
#  TokenList<Кроме, того, ,, в, боекомплекте, имеются, выстрелы, типа, ", Сеть, -, 12Х, ", ,, которые, дополнительно, обрабатывают, цель, слезоточивым, веществом, ,, что, затрудняет, ведение, противником, активных, боевых, действий, .>,
#  TokenList<В, боекомплекте, имеется, дополнительный, заряд, ", Сеть, -, 12, -, 4, ", ,, который, разбрасывает, не, одну, большую, сеть, ,, а, одновременно, несколько, сетей, меньшего, размера, .>,
#  TokenList<Варианты, исполнения, комплекса, ", КОБА, ", могут, использоваться, не, только, в, переносном, варианте, .>,
#  TokenList<Упрощенный, вариант, исполнения, ", Коба-С, ", предусматривает, установку, стреляющего, устройства, в, оборудованном, окопе, .>,
#  TokenList<Такой, вариант, наиболее, эффективен, для, ведения, охранных, мероприятий, .>,
#  TokenList<Комплекс, ", КОБА, ", может, использоваться, как, с, грунта, ,, так, и, с, бронемашин, и, транспортных, средств, .>,
#  TokenList<В, случае, использования, с, бронемашин, используется, вариант, ", Коба-Т, ", ,, имеющий, пульт, управления, с, указателем, на, панели, дистанции, выстрела, и, дистанционным, управлением, прицеливания, .>,
#  TokenList<В, таком, варианте, использования, ,, безусловно, ,, необходимо, также, применение, дополнительных, элементов, крепления, комплекса, на, броне, или, кузове, автомобиля, .>,
#  TokenList<Необходимо, заметить, ,, что, стреляющий, механизм, комплекса, работает, практически, бесшумно, .>,
#  TokenList<Выстрел, не, слышен, на, расстоянии, 5, -, 8, метров, .>,
#  TokenList<Такая, особенность, бесшумного, выстрела, затрудняет, возможность, своевременного, реагирования, противником, на, изменение, боевой, ситуации, и, практически, исключает, возможность, противодействовать, ему, .>,
#  TokenList<Конструкторское, решение, является, одним, из, ", ноу-хау, ", украинских, ученых, ,, используемым, в, данной, конструкции, комплекса, .>,
#  TokenList<На, основе, пускового, контейнера, комплекса, ", КОБА, ", разработаны, другие, системы, специального, вооружения, .>,
#  TokenList<Для, сил, чрезвычайных, ситуаций, разработаны, спасательный, комплекс, ", БАРС, -, 100К, ", ,, комплекс, для, разминирования, противопехотных, мин, ", БАРСУК, ", ,, комплекс, ", Снег, ", и, другие, .>,
#  TokenList<(, Бакланов, ,, Мертвые, сраму, не, имут, ), .>,
#  TokenList<Первыми, увидели, немцев, разведчики, .>,
#  TokenList<Из, нескошенного, ,, засыпанного, снегом, пшеничного, поля, стали, подыматься, головы, .>,
#  TokenList<Черной, ,, колеблющейся, на, ходу, ,, изломанной, цепью, они, приближались, сквозь, снег, .>,
#  TokenList<Головы, в, касках, …>,
#  TokenList<Плечи, …>,
#  TokenList<Руки, с, автоматами, .>,
#  TokenList<Все, это, подымалось, из, пшеницы, по, мере, того, как, немцы, приближались, .>,
#  TokenList<Разведчиков, вместе, с, Мостовым, было, четверо, .>,
#  TokenList<Они, лежали, в, замерзшей, водомоине, ,, разбросав, ноги, .>,
#  TokenList<Ждали, .>,
#  TokenList<Потом, их, осталось, трое, :, одного, Мостовой, послал, назад, предупредить, дивизион, .>,
#  TokenList<Ветер, дул, от, немцев, ,, и, напряженным, ухом, уже, различимы, были, шаги, и, шуршание, мертвых, колосьев, ,, сквозь, которые, они, шли, .>,
#  TokenList<А, может, ,, это, казалось, .>,
#  TokenList<Лежавший, рядом, с, Мостовым, разведчик, то, и, дело, хватал, с, земли, снег, сохнущими, губами, .>,
#  TokenList<И, оглядывался, назад, ,, где, громко, рокотали, в, низине, тракторы, .>,
#  TokenList<Взлетевшая, далеко, ракета, не, поднялась, над, гребнем, ,, только, осветила, край, низкого, неба, ,, словно, из-за, туч, .>,
#  TokenList<И, на, этом, осветившемся, небе, хорошо, и, крупно, стали, видны, с, земли, приближающиеся, немцы, .>,
#  TokenList<Они, шли, сюда, на, звук, тракторов, .>,
#  TokenList<Начав, с, левого, фланга, ,, Мостовой, успел, насчитать, двенадцать, голов, ,, и, свет, погас, .>,
#  TokenList<Он, зубами, стянул, с, правой, руки, перчатку, ,, прижал, к, щеке, холодный, приклад, автомата, ,, повозившись, ,, надежно, упер, локти, .>,
#  TokenList<Немцы, приближались, -, черные, ,, наклоненные, вперед, тени, ,, по, мушке, смещаясь, вправо, .>,
#  TokenList<Одни, сдвигались, с, нее, ,, другие, всходили, на, мушку, .>,
#  TokenList<А, в, это, время, на, середине, подъема, трактор, лебедкой, тянул, снизу, пушку, .>,
#  TokenList<На, гусенице, его, сидел, на, корточках, тракторист, Никитенко, в, черных, от, солярки, и, масла, подшитых, валенках, .>,
#  TokenList<У, радиатора, грел, руки, солдат, ,, беспокойно, оглядываясь, .>,
#  TokenList<Оказался, он, тут, по, той, самой, причине, ,, по, какой, во, время, боя, обязательно, кто-нибудь, окажется, возле, кухни, .>,
#  TokenList<Боясь, ,, что, его, прогонят, ,, он, всячески, старался, услужить, трактористу, .>,
#  TokenList<Заметил, ,, что, тот, хочет, прикурить, ,, -, поспешно, достал, из, кармана, ", Катюшу, ", ,, высек, искры, и, ,, раздув, шнур, ,, поднес, к, папироске, .>,
#  TokenList<Тот, самый, разведчик, ,, который, ходил, с, ним, и, с, Мостовым, .>,
#  TokenList<И, Васич, обрадовался, ,, увидев, его, живым, .>,
#  TokenList<Рядом, с, Халатурой, солдат, ,, хрипло, смеясь, ,, свертывал, трясущимися, пальцами, цигарку, ,, нервно, дергал, головой, .>,
#  TokenList<-, Как, _, он, нас, ,, а, ?, ., .>,
#  TokenList<Ка-ак, _, он, нас, !, ., ., !>,
#  TokenList<И, прыгающие, пальцы, просыпали, табак, .>,
#  TokenList<Другой, ,, взведя, пружину, ,, хмурясь, ,, заряжал, на, коленях, автоматный, диск, ,, торопился, ,, поглядывая, в, сторону, выстрелов, .>,
#  TokenList<Еще, слышны, были, танки, и, далеко, где-то, _, немецкие, голоса, ,, перекликавшиеся, по, лесу, .>,
#  TokenList<Бил, с, бронетранспортера, миномет, ,, и, мины, ,, задевая, за, ветки, ,, рвались, в, воздухе, ,, как, шрапнели, .>,
#  TokenList<Сюда, ,, в, глубину, леса, ,, пока, еще, достигали, редкие, пули, .>,
#  TokenList<Васич, стоял, под, деревом, ,, спиной, опершись, о, ствол, ,, сунув, руки, в, карманы, шинели, .>,
#  TokenList<Он, знал, ,, что, немцы, продвигаются, по, лесу, ,, скоро, они, будут, здесь, .>,
#  TokenList<Но, он, все, не, давал, приказа, отойти, .>,
#  TokenList<Где-то, еще, должны, быть, люди, .>,
#  TokenList<Отбившиеся, ,, прорвавшиеся, поодиночке, .>,
#  TokenList<В, Президиуме, Российской, академии, наук, (, РАН, ), 10, ноября, 2003, года, подписано, соглашение, о, сотрудничестве, между, РАН, и, горно-металлургической, компанией, ", Норильский, никель, ", .>,
#  TokenList<В, соответствии, с, ним, предприниматели, собираются, расходовать, $, 20, -, 40, млн., в, год, на, осуществление, работ, по, созданию, коммерчески, выгодного, топливного, элемента, .>,
#  TokenList<Эта, программа, по, водородной, энергетике, рассчитана, примерно, на, десять, лет, .>,
#  TokenList<Соглашение, между, учеными, и, предпринимателями, о, сотрудничестве, в, области, водородной, энергетики, и, топливных, элементов, -, первый, прецедент, ,, когда, крупный, отечественный, капитал, решил, профинансировать, научные, исследования, .>,
#  TokenList<", В, области, водородной, энергетики, у, России, есть, два, преимущества, перед, всеми, остальными, странами, -, фундаментальная, наука, и, наша, компания, ,, которая, производит, более, половины, палладия, в, мире, ,, -, сказал, на, церемонии, подписания, генеральный, директор, компании, ", Норильский, никель, ", Михаил, Прохоров, .>,
#  TokenList<Мы, надеемся, совместно, с, Академией, наук, показать, на, практике, ,, что, палладий, лежит, в, основе, водородной, технологии, -, ведь, без, него, нельзя, создавать, ни, эффективные, катализаторы, ,, ни, оборудование, для, получения, и, хранения, чистого, водорода, ", .>,
#  TokenList<Этот, проект, выгоден, обеим, сторонам, .>,
#  TokenList<Ведь, цена, металла, в, виде, изделия, возрастает, многократно, ,, и, компания, зарабатывает, дополнительные, деньги, .>,
#  TokenList<Ну, ,, а, ученые, получают, столь, необходимое, им, финансирование, .>,
#  TokenList<", Я, не, постесняюсь, сказать, ,, что, само, будущее, страны, зависит, от, того, ,, как, будет, использован, наш, интеллектуальный, потенциал, ,, -, говорит, президент, РАН, Юрий, Осипов, .>,
#  TokenList<Мы, всячески, приветствуем, стремление, крупного, бизнеса, сотрудничать, с, наукой, .>,
#  TokenList<Конечно, ,, у, нас, имеется, печальный, опыт, .>,
#  TokenList<В, свое, время, ученые, Академии, наук, много, сделали, для, разведки, основных, месторождений, нефти, и, газа, или, создания, новейших, систем, вооружений, ,, однако, мы, ничего, не, имеем, от, эксплуатации, результатов, нашей, работы, .>,
#  TokenList<Сейчас, же, мы, набрали, жизненный, опыт, и, постараемся, сделать, ,, чтобы, при, появлении, коммерческих, изделий, никто, не, оказался, в, проигрыше, .>,
#  TokenList<", У, нас, имеется, не, менее, восьми, крупных, организаций, ,, которые, активно, сотрудничают, с, частным, капиталом, ,, -, говорит, вице-президент, РАН, Геннадий, Месяц, (, лауреат, международной, энергетической, премии, ", Глобальная, энергия, ", -, CNews.ru, ), ,, который, будет, возглавлять, академическую, программу, по, водородной, энергетике, .>,
#  TokenList<Очень, хорошо, дела, идут, у, металлургов, ,, у, новосибирских, химиков, ,, которые, создают, новые, катализаторы, .>,
#  TokenList<Именно, поэтому, предприниматели, из, ", Норильского, никеля, ", пришли, к, нам, :, они, знают, ,, что, с, нами, можно, иметь, дело, .>,
#  TokenList<Сейчас, наступил, исторический, момент, -, работа, ученых, наконец, -, то, востребована, .>,
#  TokenList<В, программе, мы, планируем, объединить, усилия, примерно, двух, десятков, институтов, и, через, три, -, пять, лет, получить, коммерчески, пригодный, продукт, ", .>,
#  TokenList<Топливный, элемент, -, это, устройство, ,, в, котором, энергия, топлива, непосредственно, преобразуется, в, электрический, ток, без, использования, всевозможных, турбин, .>,
#  TokenList<Это, позволяет, существенно, ,, в, несколько, раз, ,, увеличить, коэффициент, полезного, действия, .>,
#  TokenList<Наиболее, перспективным, считается, водородный, элемент, ,, в, котором, электричество, возникает, в, результате, реакции, образования, молекулы, воды, из, ионов, водорода, и, кислорода, .>,
#  TokenList<Первая, проблема, ,, которая, стоит, перед, создателями, батареи, ,, -, разработать, дешевый, электролит, .>,
#  TokenList<Сейчас, наиболее, перспективным, материалом, считается, твердый, полимерный, электролит, или, протонная, мембрана, .>,
#  TokenList<Монополистом, на, рынке, таких, мембран, выступает, компания, ", Дюпон, ", и, стоит, этот, материал, очень, дорого, .>,
#  TokenList<В, целом, один, киловатт, мощности, батареи, обходится, примерно, в, пять, тысяч, долларов, .>,
#  TokenList<А, конкурентоспособной, по, сравнению, с, другими, источниками, энергии, топливная, батарея, становится, при, цене, в, сотню, -, другую, долларов, за, киловатт, .>,
#  TokenList<России, топливные, батареи, с, жидким, щелочным, электролитом, достались, в, наследство, от, советского, космического, челнока, ", Буран, ", .>,
#  TokenList<Впоследствии, такая, модернизированная, батарея, послужила, источником, питания, для, водородного, автомобиля, ", Нива, ", ,, который, демонстрировали, на, московском, автосалоне, 2001, года, .>,
#  TokenList<Тянет, за, шарф, -, он, разматывается, ,, хватает, за, рукав, ,, и, из, кармана, высыпаются, гвозди, .>,
#  TokenList<В, руке, зажат, молоток, .>,
#  TokenList<Откуда, он, появился, ?>,
#  TokenList<Во, сне, не, сохранилось, .>,
#  TokenList<Отчаянно, ,, в, изнеможении, она, прибивает, к, полу, и, шарф, ,, и, рукав, .>,
#  TokenList<Еще, удар, -, наотмашь, ,, главное, -, попасть, по, шляпке, .>,
#  TokenList<Пальто, распято, .>,
#  TokenList<Нет, такой, конкретной, картины, у, Марка, Шагала, .>,
#  TokenList<Но, не, счесть, ,, сколько, распятий, притулилось, бочком, в, других, его, сюжетах, .>,
#  TokenList<Когда, на, сцене, вновь, появится, плоская, фанерная, голова, коровы, ,, ты, поймешь, ,, почему, столько, грусти, на, дне, ее, глаза, -, маслины, ,, сколько, всего, ей, поведали, руки, ,, облегчавшие, вымя, .>,
#  TokenList<Многие, эпизоды, спектакля, можно, было, бы, поименовать, в, духе, наивного, художника, ,, что-нибудь, вроде, ", Женщина, и, часы, ", ,, но, две, я, бы, назвала, ", Марк, Шагал, и, театр, ", .>,
#  TokenList<Пурим, -, шпиль, актеры, ТЮЗа, разыгрывают, весело, ,, бесшабашно, ,, как, и, положено, в, балагане, ,, какого, бы, национального, происхождения, он, ни, был, .>,
#  TokenList<Здесь, всегда, храбрые, воины, сражаются, с, заклятыми, врагами, ,, чтобы, потом, в, финале, представления, отплясывать, ,, петь, и, пить, ,, празднуя, победу, .>,
#  ...]

# %%
def get_data(data_path):
    sens = read_dataset(data_path)
    res = [parse_sent(sent.tokens) for sent in sens]
    return list(zip([i[0] for i in res], [i[1] for i in res]))

def compute_initial_observer(token_lists, tag_lists):
    c = np.zeros(len(items))
    for tag_list in tag_lists:
        for t in tag_list:
            c[t] += 1

    ob = {}
    for id, tok in enumerate(token_lists):
        for idex, token in enumerate(tok):
            if token not in ob:
                ob[token] = np.zeros(len(items))
            ob[token][tag_lists[id][idex + 1]] += (1 / c[tag_lists[id][idex + 1]])

    return ob

# %%
train = get_data(SYNTAG)
for sent, tags in train[:10]:
    print(sent)
    print(tags)
    print()
# Out:
# ['анкета', '.']
# [<POS.START: 0>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.END: 18>]
#
# ['начальник', 'областной', 'управление', 'связь', 'семен', 'еремеевич', 'быть', 'человек', 'простой', ',', 'приходить', 'на', 'работа', 'всегда', 'вовремя', ',', 'здороваться', 'с', 'секретарша', 'за', 'рука', 'и', 'иногда', 'даже', 'писать', 'в', 'стенгазета', 'заметка', 'под', 'псевдоним', '"', 'муха', '"', '.']
# [<POS.START: 0>, <POS.NOUN: 8>, <POS.ADJ: 1>, <POS.NOUN: 8>, <POS.NOUN: 8>, <POS.PROPN: 12>, <POS.PROPN: 12>, <POS.AUX: 4>, <POS.NOUN: 8>, <POS.ADJ: 1>, <POS.PUNCT: 13>, <POS.VERB: 16>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.ADV: 3>, <POS.ADV: 3>, <POS.PUNCT: 13>, <POS.VERB: 16>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.CCONJ: 5>, <POS.ADV: 3>, <POS.PART: 10>, <POS.VERB: 16>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.NOUN: 8>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.PUNCT: 13>, <POS.END: 18>]
#
# ['в', 'приемная', 'он', 'с', 'утро', 'ожидать', 'посетитель', ',', '-', 'кое-кто', 'с', 'важный', 'дело', ',', 'а', 'кое-кто', 'и', 'с', 'такой', ',', 'который', 'легко', 'можно', 'быть', 'решить', 'в', 'нижестоящий', 'инстанция', ',', 'не', 'затруднять', 'семен', 'еремеевич', '.']
# [<POS.START: 0>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.PRON: 11>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.VERB: 16>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.PUNCT: 13>, <POS.PRON: 11>, <POS.ADP: 2>, <POS.ADJ: 1>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.CCONJ: 5>, <POS.PRON: 11>, <POS.PART: 10>, <POS.ADP: 2>, <POS.DET: 6>, <POS.PUNCT: 13>, <POS.PRON: 11>, <POS.ADV: 3>, <POS.ADV: 3>, <POS.AUX: 4>, <POS.VERB: 16>, <POS.ADP: 2>, <POS.ADJ: 1>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.PART: 10>, <POS.VERB: 16>, <POS.PROPN: 12>, <POS.PROPN: 12>, <POS.PUNCT: 13>, <POS.END: 18>]
#
# ['однако', 'стиль', 'работа', 'семен', 'еремеевич', 'заключаться', 'в', 'то', ',', 'чтобы', 'принимать', 'весь', 'желать', 'и', 'лично', 'вникать', 'в', 'дело', '.']
# [<POS.START: 0>, <POS.ADV: 3>, <POS.NOUN: 8>, <POS.NOUN: 8>, <POS.PROPN: 12>, <POS.PROPN: 12>, <POS.VERB: 16>, <POS.ADP: 2>, <POS.PRON: 11>, <POS.PUNCT: 13>, <POS.SCONJ: 14>, <POS.VERB: 16>, <POS.DET: 6>, <POS.VERB: 16>, <POS.CCONJ: 5>, <POS.ADV: 3>, <POS.VERB: 16>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.END: 18>]
#
# ['приемная', 'быть', 'обставить', 'просто', ',', 'но', 'по-деловому', '.']
# [<POS.START: 0>, <POS.NOUN: 8>, <POS.AUX: 4>, <POS.VERB: 16>, <POS.ADV: 3>, <POS.PUNCT: 13>, <POS.CCONJ: 5>, <POS.ADV: 3>, <POS.PUNCT: 13>, <POS.END: 18>]
#
# ['у', 'дверь', 'стоять', 'стол', 'секретарша', ',', 'на', 'стол', '-', 'писать', 'машинка', 'с', 'широкий', 'каретка', '.']
# [<POS.START: 0>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.VERB: 16>, <POS.NOUN: 8>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.VERB: 16>, <POS.NOUN: 8>, <POS.ADP: 2>, <POS.ADJ: 1>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.END: 18>]
#
# ['в', 'угол', 'висеть', 'репродуктор', 'и', 'играть', 'радио', 'для', 'развлечение', 'ожидать', 'и', 'еще', 'для', 'то', ',', 'чтобы', 'заглушать', 'голос', 'начальник', ',', 'доноситься', 'из', 'кабинет', ',', 'так', 'как', ',', 'бесспорно', ',', 'среди', 'посетитель', 'мочь', 'находиться', 'и', 'случайный', 'человек', '.']
# [<POS.START: 0>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.VERB: 16>, <POS.NOUN: 8>, <POS.CCONJ: 5>, <POS.VERB: 16>, <POS.NOUN: 8>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.VERB: 16>, <POS.CCONJ: 5>, <POS.ADV: 3>, <POS.ADP: 2>, <POS.PRON: 11>, <POS.PUNCT: 13>, <POS.SCONJ: 14>, <POS.VERB: 16>, <POS.NOUN: 8>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.VERB: 16>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.ADV: 3>, <POS.SCONJ: 14>, <POS.PUNCT: 13>, <POS.ADV: 3>, <POS.PUNCT: 13>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.VERB: 16>, <POS.VERB: 16>, <POS.PART: 10>, <POS.ADJ: 1>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.END: 18>]
#
# ['кабинет', 'отличаться', 'скромность', ',', 'присущий', 'семен', 'еремеевич', '.']
# [<POS.START: 0>, <POS.NOUN: 8>, <POS.VERB: 16>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.ADJ: 1>, <POS.PROPN: 12>, <POS.PROPN: 12>, <POS.PUNCT: 13>, <POS.END: 18>]
#
# ['в', 'глубина', 'стоять', 'широкий', 'письменный', 'стол', 'с', 'бронзовый', 'чернильница', 'и', 'перед', 'он', 'два', 'кожаный', 'кресло', '.']
# [<POS.START: 0>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.VERB: 16>, <POS.ADJ: 1>, <POS.ADJ: 1>, <POS.NOUN: 8>, <POS.ADP: 2>, <POS.ADJ: 1>, <POS.NOUN: 8>, <POS.CCONJ: 5>, <POS.ADP: 2>, <POS.PRON: 11>, <POS.NUM: 9>, <POS.ADJ: 1>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.END: 18>]
#
# ['справа', 'быть', 'стол', 'для', 'заседание', '-', 'длинный', ',', 'накрыть', 'зеленый', 'сукно', 'и', 'с', 'оба', 'сторона', 'аккуратно', 'заставить', 'стул', '.']
# [<POS.START: 0>, <POS.ADV: 3>, <POS.VERB: 16>, <POS.NOUN: 8>, <POS.ADP: 2>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.ADJ: 1>, <POS.PUNCT: 13>, <POS.VERB: 16>, <POS.ADJ: 1>, <POS.NOUN: 8>, <POS.CCONJ: 5>, <POS.ADP: 2>, <POS.NUM: 9>, <POS.NOUN: 8>, <POS.ADV: 3>, <POS.VERB: 16>, <POS.NOUN: 8>, <POS.PUNCT: 13>, <POS.END: 18>]

# %%
def helper_compute_normalized(transitions):
    s = np.sum(transitions, axis=1)
    s[POS.END] = np.sum(transitions[:, POS.END])
    dx = np.zeros((len(items), len(items)))
    for i in range(len(transitions)):
        if s[i] > 0:
            dx[i][:] = np.divide(transitions[i][:], s[i])
    return dx


def learn_transitions(tag_lists):
    """ [START, tag, tag, ..., END] """
    transitions = np.zeros((len(POS), len(POS)))
    for unit_list in tag_lists:
        for i in range(len(unit_list) - 1):
            transitions[unit_list[i], unit_list[i + 1]] += 1

    s = np.sum(transitions, axis=1)
    s[POS.END] = np.sum(transitions[:, POS.END])

    div = np.zeros((len(POS), len(POS)))
    for i in range(len(transitions)):
        if s[i] > 0:
            div[i][:] = np.divide(transitions[i][:], s[i])

    return div


def train_test_split(data, train: float, shuffle=False):
    if shuffle:
        random.shuffle(data)
    len_ = len(data)
    idx = round(len_ * train)
    train_ = data[:idx]
    test_ = data[idx:]
    return train_, test_

# %%
def train_markov(dataset):
    token_lists, tag_lists = zip(*dataset)
    tss = learn_transitions(tag_lists)
    oss = compute_initial_observer(token_lists, tag_lists)
    return tss, oss

def helper_compute_probs(trans, T, tokens, M, B, unknown_tokens, obs):
    for t in range(2, T - 1):
        for s in range(1, len(items) - 1):
            state_probs = M[:, t - 1] * trans[:, s]
            max_prob_state = int(np.argmax(state_probs))
            M[s, t] = state_probs[max_prob_state] * obs[tokens[t - 1]][s]
            B[s, t - 1] = max_prob_state

    state_probs = M[:, T - 2] * trans[:, len(items) - 1]
    max_prob_state = int(np.argmax(state_probs))
    M[len(items) - 1, T - 1] = state_probs[max_prob_state]
    B[len(items ) - 1, T - 2] = max_prob_state

    T = B.shape[1] + 1
    path = np.zeros(T, dtype=np.int)
    path[T - 1] = POS.END
    for t in range(T - 1, 0, -1):
        path[t - 1] = B[path[t], t - 1]
    return path, unknown_tokens

def report_count(sens_acc, tot_acc, unn_acc):
    return [
        'sentence accuracy - {}'.format(sens_acc),
        'token    accuracy - {}'.format(tot_acc),
        'unknown  tokens   - {}'.format(unn_acc),
    ]

def viterbi(tokens, trans, obs):
    unknown_tokens = []
    T = len(tokens) + 2
    X = np.zeros((len(items), T))
    B = np.zeros((len(items), T - 1), dtype=np.int)
    X[0, 0] = 1
    for t in tokens:
        if t not in obs:
            obs[t] = np.ones(len(items))
            unknown_tokens.append(t)
    for s in range(1, len(items)):
        X[s, 1] = trans[0, s] * obs[tokens[0]][s]

    return helper_compute_probs(trans, T, tokens, X, B, unknown_tokens, obs)


def evaluate(data, trans, obs):
    ground_truth, predictions = [], []

    corr = 0
    unknown_tokens = []
    all_tokens_count = 0

    for idx, item in enumerate(data):
        tokens = item[0]
        tags = item[1]

        all_tokens_count += len(tokens)

        predicted_tags, ut = viterbi(tokens, trans, obs)
        unknown_tokens.extend(ut)

        predictions.extend(predicted_tags)
        ground_truth.extend(tags)

        correspond = np.asarray([1 if p == t else 0 for p, t in zip(predicted_tags, tags)])
        corr += np.prod(correspond)

    sens_acc = corr / len(data)
    tot_acc = accuracy_score(ground_truth, predictions)
    unn_acc = len(unknown_tokens) / all_tokens_count
    return report_count(sens_acc, tot_acc, unn_acc)

# %%
def run_train_test_eval(train_dataset, fraction=0.8):

    train_data, test_data = train_test_split(train_dataset, fraction, shuffle=True)
    tts, obs = train_markov(train_data)

    results = evaluate(test, tts, obs)
    print('Model Results:')
    print("\n".join(results))
    return tts, obs, results

# %%
dataset = get_data(SYNTAG)

# %%
train, test = train_test_split(dataset, 0.8, shuffle=True)

# %%
results = run_train_test_eval(dataset, 0.8)
# Out:
# Model Results:
# sentence accuracy - 0.7115640684215917
# token    accuracy - 0.9785820857128158
# unknown  tokens   - 0.004260941181853538

# %%
import numpy as np
for train_fraction in np.arange(0.1, 1, 0.1):
    print('train fraction {}'.format(train_fraction))
    run_train_test_eval(dataset, train_fraction)
    print('=====')
# Out:
# train fraction 0.1
# Model Results:
# sentence accuracy - 0.4326538973676124
# token    accuracy - 0.9446005041930339
# unknown  tokens   - 0.05145157969389856
# =====
# train fraction 0.2
# Model Results:
# sentence accuracy - 0.5257605244289665
# token    accuracy - 0.958723053969234
# unknown  tokens   - 0.036438196335018644
# =====
# train fraction 0.30000000000000004
# Model Results:
# sentence accuracy - 0.5889583119942641
# token    accuracy - 0.96573030817513
# unknown  tokens   - 0.025983162133101506
# =====
# train fraction 0.4
# Model Results:
# sentence accuracy - 0.6232715353887125
# token    accuracy - 0.970298914441529
# unknown  tokens   - 0.019823385417858205
# =====
# train fraction 0.5
# Model Results:
# sentence accuracy - 0.6584041790433268
# token    accuracy - 0.9734475484899933
# unknown  tokens   - 0.014212669579739653
# =====
# train fraction 0.6
# Model Results:
# sentence accuracy - 0.6783775478848715
# token    accuracy - 0.9756495343931677
# unknown  tokens   - 0.010334927135046098
# =====
# train fraction 0.7000000000000001
# Model Results:
# sentence accuracy - 0.6967120762060842
# token    accuracy - 0.9773216031280547
# unknown  tokens   - 0.006926174189563268
# =====
# train fraction 0.8
# Model Results:
# sentence accuracy - 0.7113592133565503
# token    accuracy - 0.9785203477902968
# unknown  tokens   - 0.004443961474228455
# =====
# train fraction 0.9
# Model Results:
# sentence accuracy - 0.7270306258322237
# token    accuracy - 0.9798014096825641
# unknown  tokens   - 0.0020818558257646815
# =====
